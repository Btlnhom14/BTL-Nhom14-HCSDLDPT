# %%
import cv2
import numpy as np
from sklearn.cluster import KMeans
import os
import csv
from rembg import remove
from PIL import Image
import io

# %%
def imread_unicode(path):
    try:
        stream = np.fromfile(path, dtype=np.uint8)
        image = cv2.imdecode(stream, cv2.IMREAD_COLOR)
        return image
    except Exception as e:
        print(f"[LỖI imread_unicode] {path}: {e}")
        return None

# %%
def extract_hsv_histogram(image, h_bins=18, s_bins=8, v_bins=8):
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist_h = cv2.calcHist([hsv], [0], None, [h_bins], [0, 180])
    hist_s = cv2.calcHist([hsv], [1], None, [s_bins], [0, 256])
    hist_v = cv2.calcHist([hsv], [2], None, [v_bins], [0, 256])
    hist = np.concatenate([hist_h, hist_s, hist_v]).flatten()
    hist /= hist.sum()
    return hist

# %%
def extract_dominant_colors(image, k=3):
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    pixels = image_rgb.reshape(-1, 3)

    kmeans = KMeans(n_clusters=k, n_init=10)
    kmeans.fit(pixels)

    colors = kmeans.cluster_centers_
    counts = np.bincount(kmeans.labels_)
    percentages = counts / counts.sum()

    features = []
    for i in range(k):
        features.extend(colors[i])        # R, G, B
        features.append(percentages[i])   # Tỉ lệ %
    return np.array(features)

# %%
def process_image(image_path, hsv_bins=(18, 8, 8), kmeans_k=3):
    image = imread_unicode(image_path)
    if image is None:
        print(f"[LỖI] Không đọc được ảnh: {image_path}")
        return None
    image = cv2.resize(image, (600, 400))
    hsv_feat = extract_hsv_histogram(image, *hsv_bins)
    kmeans_feat = extract_dominant_colors(image, k=kmeans_k)
    return np.concatenate([hsv_feat, kmeans_feat])

# %%
def extract_features_from_folder(folder_path, output_csv):
    header = [f"hsv_{i}" for i in range(18 + 8 + 8)]  # HSV = 34 chiều
    header += [f"kmeans_r{i//4+1}" if i % 4 == 0 else
               f"kmeans_g{i//4+1}" if i % 4 == 1 else
               f"kmeans_b{i//4+1}" if i % 4 == 2 else
               f"kmeans_p{i//4+1}" for i in range(3 * 4)]  # K-means = 12 chiều
    header = ['filename'] + header

    with open(output_csv, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(header)

        for file in os.listdir(folder_path):
            filename = os.fsdecode(file)
            if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
                path = os.path.join(folder_path, filename)
                features = process_image(path)
                if features is not None:
                    writer.writerow([filename] + features.tolist())
                    print(f"✔ Đã xử lý: {filename}")
                else:
                    print(f"✘ Lỗi xử lý: {filename}")

# %%
# Đường dẫn đến thư mục chứa ảnh và file CSV đầu ra
folder_path = "../../data"  # hoặc chỉnh đường dẫn tùy vào cấu trúc của bạn
output_csv = "features.csv"

extract_features_from_folder(folder_path, output_csv)
# Out:
# ✔ Đã xử lý: beautiful-background-image-wild-robin-600nw-1886402566.jpg
# ✔ Đã xử lý: bird-7629852_640.jpg
# ✔ Đã xử lý: bird-9362267_640.jpg
# ✔ Đã xử lý: bird-9370168_640.jpg
# ✔ Đã xử lý: bird-9563228_640.jpg
# ✔ Đã xử lý: bird-crow-black-animal-53187.jpeg
# ✔ Đã xử lý: blue-bird-perches-atop-branch-600nw-2540912789.jpg
# ✔ Đã xử lý: blue-bird-ultramarine-flycatcher-superciliaris-600nw-508244377.jpg
# ✔ Đã xử lý: bluebird-9572585_640.jpg
# ✔ Đã xử lý: bluethroat-bird-perches-gracefully-on-600nw-2525660753.jpg
# ✔ Đã xử lý: chiffchaff-9543492_640.jpg
# ✔ Đã xử lý: colseup-mrsgoulds-sunbird-perched-on-600nw-2009331875.jpg
# ✔ Đã xử lý: eastern-bluebird-9565389_640.jpg
# ✔ Đã xử lý: eastern-bluebird-on-flowering-redbud-600nw-107858477.jpg
# ✔ Đã xử lý: european-robin-perches-gracefully-on-600nw-2556437765.jpg
# ✔ Đã xử lý: fascinated-blue-orange-bird-perching-600nw-1567637725.jpg
# ✔ Đã xử lý: feedback-white-throated-sparrow-9565381_1280.jpg
# ✔ Đã xử lý: free-photo-of-aves.jpeg
# ✔ Đã xử lý: free-photo-of-benteveo-rayado.jpeg
# ✔ Đã xử lý: free-photo-of-c-n-c-nh-m-t-chu-chim-h-a-mi-tren-canh-cay.jpeg
# ✔ Đã xử lý: free-photo-of-chan-dung-c-n-c-nh-c-a-m-t-con-qu-nha-d-u.jpeg
# ✔ Đã xử lý: free-photo-of-chan-dung-loai-v-t-duoi-dai-d-r-c-r-naxos.jpeg
# ✔ Đã xử lý: free-photo-of-chim-canh-d-ng-d-ng-c-qu.jpeg
# ✔ Đã xử lý: free-photo-of-chim-gi-cui-xanh-trong-b-i-c-nh-khu-v-n-t-i-t-t.jpeg
# ✔ Đã xử lý: free-photo-of-chim-h-ng-y-ph-ng-b-c-s-ng-d-ng-d-u-ngoai-tr-i.jpeg
# ✔ Đã xử lý: free-photo-of-chim-hinh-n-n-ch-p-nh-d-ng-v-t-c-t.jpeg
# ✔ Đã xử lý: free-photo-of-chim-puffin-d-n-s-c-d-u-tren-d-nh-vach-da-iceland.jpeg
# ✔ Đã xử lý: free-photo-of-chim-r-ng-cay-thu-v-t.jpeg
# ✔ Đã xử lý: free-photo-of-chim-robin-chau-au-d-u-tren-canh-cay-r-ng.jpeg
# ✔ Đã xử lý: free-photo-of-chim-s-ng-c-h-ng-cai.jpeg
# ✔ Đã xử lý: free-photo-of-dong-phoebe.jpeg
# ✔ Đã xử lý: free-photo-of-th-i-gian.jpeg
# ✔ Đã xử lý: free-photo-of-thien-nhien-chim-thu-v-t-d-ng-v-t (1).jpeg
# ✔ Đã xử lý: free-photo-of-thien-nhien-chim-thu-v-t-d-ng-v-t.jpeg
# ✔ Đã xử lý: gettyimages-109393772-612x612.jpg
# ✔ Đã xử lý: gettyimages-1129916016-612x612.jpg
# ✔ Đã xử lý: gettyimages-114945454-612x612.jpg
# ✔ Đã xử lý: gettyimages-1160561742-612x612.jpg
# ✔ Đã xử lý: gettyimages-117149630-612x612.jpg
# ✔ Đã xử lý: gettyimages-1178066553-612x612.jpg
# ✔ Đã xử lý: gettyimages-1188674062-612x612.jpg
# ✔ Đã xử lý: gettyimages-1192300351-612x612.jpg
# ✔ Đã xử lý: gettyimages-1251401870-612x612.jpg
# ✔ Đã xử lý: gettyimages-1269409940-612x612.jpg
# ✔ Đã xử lý: gettyimages-1290109200-612x612.jpg
# ✔ Đã xử lý: gettyimages-1351309842-612x612.jpg
# ✔ Đã xử lý: gettyimages-1457818742-612x612.jpg
# ✔ Đã xử lý: gettyimages-1459784086-612x612.jpg
# ✔ Đã xử lý: gettyimages-1465706170-612x612.jpg
# ✔ Đã xử lý: gettyimages-150542553-612x612.jpg
# ✔ Đã xử lý: gettyimages-1536440902-612x612.jpg
# ✔ Đã xử lý: gettyimages-1540663240-612x612.jpg
# ✔ Đã xử lý: gettyimages-154904597-612x612.jpg
# ✔ Đã xử lý: gettyimages-200396796-001-612x612.jpg
# ✔ Đã xử lý: gettyimages-2008168059-612x612.jpg
# ✔ Đã xử lý: gettyimages-2163681161-612x612.jpg
# ✔ Đã xử lý: gettyimages-2172961347-612x612.jpg
# ✔ Đã xử lý: gettyimages-2188975567-612x612.jpg
# ✔ Đã xử lý: gettyimages-453905173-612x612.jpg
# ✔ Đã xử lý: gettyimages-953005346-612x612.jpg
# ✔ Đã xử lý: gettyimages-968383308-612x612.jpg
# ✔ Đã xử lý: hummingbird-6565805_640.jpg
# ✔ Đã xử lý: istockphoto-1030966828-612x612.jpg
# ✔ Đã xử lý: istockphoto-1032674926-612x612.jpg
# ✔ Đã xử lý: istockphoto-1053410094-612x612.jpg
# ✔ Đã xử lý: istockphoto-1060742980-612x612.jpg
# ✔ Đã xử lý: istockphoto-1073356412-612x612.jpg
# ✔ Đã xử lý: istockphoto-108221750-612x612.jpg
# ✔ Đã xử lý: istockphoto-1093691338-612x612.jpg
# ✔ Đã xử lý: istockphoto-1132039168-612x612.jpg
# ✔ Đã xử lý: istockphoto-1135506483-612x612.jpg
# ✔ Đã xử lý: istockphoto-1142706172-612x612.jpg
# ✔ Đã xử lý: istockphoto-115518507-612x612.jpg
# ✔ Đã xử lý: istockphoto-117149630-612x612.jpg
# ✔ Đã xử lý: istockphoto-1191223442-612x612.jpg
# ✔ Đã xử lý: istockphoto-1224588778-612x612.jpg
# ✔ Đã xử lý: istockphoto-1226522786-612x612.jpg
# ✔ Đã xử lý: istockphoto-1255640039-612x612.jpg
# ✔ Đã xử lý: istockphoto-1281342326-612x612.jpg
# ✔ Đã xử lý: istockphoto-1287355609-612x612.jpg
# ✔ Đã xử lý: istockphoto-1295661940-612x612.jpg
# ✔ Đã xử lý: istockphoto-1302381938-612x612.jpg
# ✔ Đã xử lý: istockphoto-1318557209-640x640.jpg
# ✔ Đã xử lý: istockphoto-1321252712-612x612.jpg
# ✔ Đã xử lý: istockphoto-1330403392-612x612.jpg
# ✔ Đã xử lý: istockphoto-1338978885-612x612.jpg
# ✔ Đã xử lý: istockphoto-1349883787-612x612.jpg
# ✔ Đã xử lý: istockphoto-1363627663-612x612.jpg
# ✔ Đã xử lý: istockphoto-1371999595-612x612.jpg
# ✔ Đã xử lý: istockphoto-1397310010-612x612.jpg
# ✔ Đã xử lý: istockphoto-139897715-612x612.jpg
# ✔ Đã xử lý: istockphoto-1452060300-640x640.jpg
# ✔ Đã xử lý: istockphoto-1472678552-612x612.jpg
# ✔ Đã xử lý: istockphoto-1486349490-612x612.jpg
# ✔ Đã xử lý: istockphoto-1489154382-612x612.jpg
# ✔ Đã xử lý: istockphoto-157291745-612x612.jpg
# ✔ Đã xử lý: istockphoto-157424683-612x612.jpg
# ✔ Đã xử lý: istockphoto-1732009136-640x640.jpg
# ✔ Đã xử lý: istockphoto-173584960-612x612.jpg
# ✔ Đã xử lý: istockphoto-1818776666-640x640.jpg
# ✔ Đã xử lý: istockphoto-183412466-612x612.jpg
# ✔ Đã xử lý: istockphoto-2061414217-612x612.jpg
# ✔ Đã xử lý: istockphoto-2163681161-612x612.jpg
# ✔ Đã xử lý: istockphoto-2181795206-612x612.jpg
# ✔ Đã xử lý: istockphoto-481526876-612x612.jpg
# ✔ Đã xử lý: istockphoto-508793354-612x612.jpg
# ✔ Đã xử lý: istockphoto-519501240-612x612.jpg
# ✔ Đã xử lý: istockphoto-540128322-612x612.jpg
# ✔ Đã xử lý: istockphoto-623347472-612x612.jpg
# ✔ Đã xử lý: istockphoto-909402044-612x612.jpg
# ✔ Đã xử lý: jay-on-ast-634405_640.jpg
# ✔ Đã xử lý: kiskadee-9473956_640.jpg
# ✔ Đã xử lý: mourning-dove-5552510_640.jpg
# ✔ Đã xử lý: northern-hawk-owl-6961772_640.jpg
# ✔ Đã xử lý: nuthatch-sitta-europaea-bird-portrait-600nw-2411587149.jpg
# ✔ Đã xử lý: pexels-agrosales-31890485.jpg
# ✔ Đã xử lý: pexels-agrosales-31890489.jpg
# ✔ Đã xử lý: pexels-agrosales-31890522.jpg
# ✔ Đã xử lý: pexels-agrosales-31890527.jpg
# ✔ Đã xử lý: pexels-calvinseng-31916493.jpg
# ✔ Đã xử lý: pexels-charmain-31875554.jpg
# ✔ Đã xử lý: pexels-chris-f-38966-31891005.jpg
# ✔ Đã xử lý: pexels-glacika67-31910634.jpg
# ✔ Đã xử lý: pexels-guvo59-31902756.jpg
# ✔ Đã xử lý: pexels-guvo59-31902759.jpg
# ✔ Đã xử lý: pexels-jay-brand-1763356224-31917906.jpg
# ✔ Đã xử lý: pexels-jay-brand-1763356224-31917908.jpg
# ✔ Đã xử lý: pexels-jay-brand-1763356224-31917911.jpg
# ✔ Đã xử lý: pexels-nelson-marulanda-708254-31889017.jpg
# ✔ Đã xử lý: pexels-nikola-tomasic-58494762-31899485.jpg
# ✔ Đã xử lý: pexels-photo-1213920.jpeg
# ✔ Đã xử lý: pexels-photo-1581103.jpeg
# ✔ Đã xử lý: pexels-photo-1676067.jpeg
# ✔ Đã xử lý: pexels-photo-2000171.jpeg
# ✔ Đã xử lý: pexels-photo-2119186.jpeg
# ✔ Đã xử lý: pexels-photo-2121673.jpeg
# ✔ Đã xử lý: pexels-photo-2167039.jpeg
# ✔ Đã xử lý: pexels-photo-221417.jpeg
# ✔ Đã xử lý: pexels-photo-2265252.jpeg
# ✔ Đã xử lý: pexels-photo-2317904.jpeg
# ✔ Đã xử lý: pexels-photo-2333302.jpeg
# ✔ Đã xử lý: pexels-photo-2339335.jpeg
# ✔ Đã xử lý: pexels-photo-2398575.jpeg
# ✔ Đã xử lý: pexels-photo-2570085.jpeg
# ✔ Đã xử lý: pexels-photo-2575705.jpeg
# ✔ Đã xử lý: pexels-photo-2601519.jpeg
# ✔ Đã xử lý: pexels-photo-2769633.jpeg
# ✔ Đã xử lý: pexels-photo-2827104.jpeg
# ✔ Đã xử lý: pexels-photo-286635.jpeg
# ✔ Đã xử lý: pexels-photo-2947149.jpeg
# ✔ Đã xử lý: pexels-photo-2962592.jpeg
# ✔ Đã xử lý: pexels-photo-2972520.jpeg
# ✔ Đã xử lý: pexels-photo-31839925.jpeg
# ✔ Đã xử lý: pexels-photo-31891005.jpeg
# ✔ Đã xử lý: pexels-photo-31917911.jpeg
# ✔ Đã xử lý: pexels-photo-3379017.jpeg
# ✔ Đã xử lý: pexels-photo-3525682.jpeg
# ✔ Đã xử lý: pexels-photo-3584125.jpeg
# ✔ Đã xử lý: pexels-photo-3832408.jpeg
# ✔ Đã xử lý: pexels-photo-3834316.jpeg
# ✔ Đã xử lý: pexels-photo-3839570.jpeg
# ✔ Đã xử lý: pexels-photo-469315.jpeg
# ✔ Đã xử lý: pexels-photo-693984.jpeg
# ✔ Đã xử lý: pexels-photo-709754.jpeg
# ✔ Đã xử lý: pexels-photo-7414659.jpeg
# ✔ Đã xử lý: pexels-photo-832775.jpeg
# ✔ Đã xử lý: pexels-photo-953130.jpeg
# ✔ Đã xử lý: pexels-rajesh-s-balouria-1289088-31908952.jpg
# ✔ Đã xử lý: pexels-rajesh-s-balouria-1289088-31908962.jpg
# ✔ Đã xử lý: pexels-robert-schwarz-1488822070-31895264.jpg
# ✔ Đã xử lý: pexels-robert-schwarz-1488822070-31912777.jpg
# ✔ Đã xử lý: pexels-robert-schwarz-1488822070-31912781.jpg
# ✔ Đã xử lý: pexels-robertkso-31889103.jpg
# ✔ Đã xử lý: pexels-tineke-posthoorn-3827772-31901578.jpg
# ✔ Đã xử lý: pexels-wei86_travel-th-31932701-31928892.jpg
# ✔ Đã xử lý: pexels-wei86_travel-th-31932701-31928895.jpg
# ✔ Đã xử lý: photo-1516681685438-72299830a906.jpg
# ✔ Đã xử lý: photo-1522926193341-e9ffd686c60f.jpg
# ✔ Đã xử lý: photo-1620748741969-c68debdd255e.jpg
# ✔ Đã xử lý: photo-1669617576741-845b4f46f7b3.jpg
# ✔ Đã xử lý: photo-1672220371154-34a10c19dbc5.jpg
# ✔ Đã xử lý: photo-1681001826125-daff8902a0ec.jpg
# ✔ Đã xử lý: photo-1700397341384-3ad0553ef86c.jpg
# ✔ Đã xử lý: photo-1700397341418-fee8e34aafcf.jpg
# ✔ Đã xử lý: photo-1706245260677-7c9526e1f42c.jpg
# ✔ Đã xử lý: photo-1706245438313-f1af6bf94f84.jpg
# ✔ Đã xử lý: photo-1716324093121-df91fccfea2f.jpg
# ✔ Đã xử lý: photo-1735333174309-0cfa60c03240.jpg
# ✔ Đã xử lý: premium_photo-1668201495517-836a17ecae14.jpg
# ✔ Đã xử lý: premium_photo-1668208363412-8f668417e44e.jpg
# ✔ Đã xử lý: premium_photo-1668225015105-deb9cdf4e256.jpg
# ✔ Đã xử lý: premium_photo-1675714692342-01dfd2e6b6b5.jpg
# ✔ Đã xử lý: purple-grenadier-bird-perched-on-600nw-2086697161.jpg
# ✔ Đã xử lý: redandgreen-macaw-ara-chloroptera-pauses-600nw-2505389679.jpg
# ✔ Đã xử lý: scarlet-honeyeater-bird-red-feathers.jpg
# ✔ Đã xử lý: sparrow-5875379_640.jpg
# ✔ Đã xử lý: sri-lanka-whiteeye-bird-perched-600nw-2132414103.jpg
# ✔ Đã xử lý: wagtail-6211745_640.jpg
# ✔ Đã xử lý: white-canary-bird-perched-softbox-600nw-2053822370.jpg
# ✔ Đã xử lý: white-yellow-canary-bird-perched-600nw-2053896281.jpg
# ✔ Đã xử lý: willie-wagtail-9387293_640.jpg
# ✔ Đã xử lý: willow-warbler-8071471_640.jpg
